# %% [markdown]
# # Cleaning, EDA, Visualizing and Predicting 'Life Expectancy'

# %% [markdown]
# ### Importing necessary libraries

# %%
# importing data analysis libraries

import pandas as pd 
import numpy as np

# %%
# importing data visualization libraries

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ### Exploring dataset

# %%
# sample of data 

df.sample(10)
# Out:
#                                Country  Year      Status  Life expectancy   \
# 735   Democratic Republic of the Congo  2001  Developing              51.8
# 2791       United Republic of Tanzania  2002  Developing              52.0
# 2240                      Saudi Arabia  2008  Developing              73.3
# 2784       United Republic of Tanzania  2009  Developing              56.9
# 1933                              Oman  2008  Developing              75.2
# 595                            Comoros  2012  Developing              62.5
# 1510                             Libya  2011  Developing              71.3
# 1330                            Jordan  2015  Developing              74.1
# 1240                              Iraq  2009  Developing              74.0
# 2242                      Saudi Arabia  2006  Developing              73.2
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 735              34.0            227     1.90                0.000000
# ...

# %%
# info about data columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# describing numerical columns in a statistical way

df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
# describing non-numerical columns in a statistical way

df.describe(include ='object').transpose()
# Out:
#         count unique          top  freq
# Country  2938    193  Afghanistan    16
# Status   2938      2   Developing  2426

# %%
# knowing no. of unique values in each column

df.nunique()
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# Alcohol                            1076
# percentage expenditure             2328
# Hepatitis B                          87
# Measles                             958
#  BMI                                608
# under-five deaths                   252
# Polio                                73
# Total expenditure                   818
# Diphtheria                           81
#  HIV/AIDS                           200
# GDP                                2490
# Population                         2278
#  thinness  1-19 years               200
#  thinness 5-9 years                 207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %%
# check for null values

df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# null values in percentage

df.isnull().sum()/2938 *100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %% [markdown]
# ## Data cleaning

# %%
# handling spaces in data column names

df.columns = df.columns.str.strip()

# %%
# columns names

df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ## Visualizing data

# %% [markdown]
# ### Show Data Distrubution

# %%
# split data into numerical

numeric_col = df.select_dtypes(exclude ='object')
numeric_col = numeric_col.drop('Year',axis=1)
numeric_col.columns
# Out:
# Index(['Life expectancy', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# show distrubution using histgram

for col in numeric_col:
    sns.histplot(numeric_col[col],kde = True)
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# #### from histgram most of columns have a skewness

# %% [markdown]
# ### Check the outliers

# %%
# check the outliers using  boxplot

for col in numeric_col:
    sns.boxplot(numeric_col[col])
    plt.title(col)
    plt.show()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(12, 5))

# Plot the bar chart

plt.subplot(1, 2, 1)
bar_colors = ['#0059FF', '#FF8700'] 
plt.bar(df["Status"].value_counts().index, df["Status"].value_counts(), color=bar_colors)
plt.xlabel('Values')
plt.ylabel('Counts')
plt.title('Value Counts of Status')

# Plot the pie chart

plt.subplot(1, 2, 2)
pie_colors = ['#0059FF', '#FF8700'] 
plt.pie(df["Status"].value_counts(), labels=df["Status"].value_counts().index, autopct='%1.1f%%', startangle=90, colors=pie_colors)
plt.title('Proportion of Status')

# Show the plot
plt.show()

# %%
# relation between 'Adult Morality' and 'Status'

sns.countplot(df['Adult Mortality'],hue = df['Status'])
plt.show()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# values of 'Year'

df['Year'].unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000], dtype=int64)

# %%
# visualize the avgerage life expectancy in each year

avg_life_expectancy = df.groupby('Year')['Life expectancy'].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.plot(avg_life_expectancy['Year'], avg_life_expectancy['Life expectancy'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average Life Expectancy')
plt.title('Average Life Expectancy Over the Years')
plt.grid(True)
plt.show()

# %%
# visualize the avgerage life expectancy in each year

avg_infant_deaths = df.groupby('Year')['infant deaths'].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.plot(avg_infant_deaths['Year'], avg_infant_deaths['infant deaths'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average infant deaths')
plt.title('Average infant deaths Over the Years')
plt.grid(True)
plt.show()

# %%
# relation between features and terget

columns = df.drop(['Country','Year','Status','Life expectancy'],axis =1)
for col in columns:
    sns.scatterplot(data = columns ,x = col, y = df['Life expectancy'])
    plt.show()

# %% [markdown]
# ## Correlation

# %%
# visualize the correlation between columns in numerical way

plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
# correlation between all columns and the target column

correlation_matrix = df.corr()
life_expectancy_corr = correlation_matrix['Life expectancy']
print("Correlation between 'Life Expectancy' and other columns:")
print(life_expectancy_corr)
# Out:
# Correlation between 'Life Expectancy' and other columns:
# Year                               0.170033
# Life expectancy                    1.000000
# Adult Mortality                   -0.696359
# infant deaths                     -0.196557
# Alcohol                            0.404877
# percentage expenditure             0.381864
# Hepatitis B                        0.256762
# Measles                           -0.157586
# BMI                                0.567694
# under-five deaths                 -0.222529
# Polio                              0.465556
# Total expenditure                  0.218086
# Diphtheria                         0.479495
# HIV/AIDS                          -0.556556
# GDP                                0.461455
# Population                        -0.021538
# thinness  1-19 years              -0.477183
# thinness 5-9 years                -0.471584
# Income composition of resources    0.724776
# Schooling                          0.751975
# ...

# %% [markdown]
# #### * from the data exploration we conclude :
#
# #####  1- there 's a null values in columns [life expectancy , adult mortality ,Alcohol ,hepatitis ,Bmi ,Total expenditure,Diphtheria ,GDP,population thinness  1-19 years,
#  thinness 5-9 years,
# Income composition of resources,
# Schooling,
#
# ##### 2- most features are skewed data and alot of outliers
#
# #####  3- droped columns [country ,percentage expenditure, under five deaths , thinness 5-9]

# %%
mean_country_life = df.groupby('Country')['Life expectancy'].mean().reset_index()
plt.figure(figsize=(12, 8))
sns.violinplot(x=mean_country_life['Life expectancy'])
plt.xlabel('Life Expectancy')
plt.title('Distribution of Mean Life Expectancy by Country')
plt.show()

# %% [markdown]
# ### The average life expectancy age is in range [70,80]
# ### There are skewness in the data

# %%
sns.lineplot(df['Year'],df['Life expectancy'])
plt.show()
sns.lineplot(df['Year'],df['Adult Mortality'])
plt.show()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### get the top countries have high and law death rate

# %%
top_country_death = df.nlargest(20,'Adult Mortality')
top_country_death
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2932  Zimbabwe  2005  Developing             44.6            717.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 349   Botswana  2002  Developing             46.0            699.0
# 348   Botswana  2003  Developing             46.4            693.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 1127     Haiti  2010  Developing             36.3            682.0
# 350   Botswana  2001  Developing             46.7            679.0
# 1484   Lesotho  2005  Developing             44.5            675.0
# 1485   Lesotho  2004  Developing             44.8            666.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
# 1483   Lesotho  2006  Developing             45.3            654.0
# 347   Botswana  2004  Developing             48.1            652.0
# ...

# %%
sns.barplot(y=top_country_death['Country'],x=top_country_death['Adult Mortality'])
plt.show()

# %%
top_country_life = df.nlargest(20 ,'Life expectancy')
sns.barplot(x = top_country_life['Life expectancy'], y= top_country_life['Country'])
plt.show()

# %%
sns.lineplot(df['Hepatitis B'],df['Life expectancy'])
plt.show()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Handling null values:
# ​
# #### the distrubution of the features are skewed so we will use the median for fill the null  value

# %%
# before handling null values

df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.fillna(df.median(),inplace = True)
# Out:
# C:\Users\Mohamed\AppData\Local\Temp\ipykernel_6084\3619658944.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median(),inplace = True)

# %%
# after handling null values

df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ### Handling outlier using IQR

# %%
for column in df.select_dtypes(exclude='object'):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    lower_outliers = (df[column] < lower)
    upper_outliers = (df[column] > upper)
    df.loc[lower_outliers, column] = q1
    df.loc[upper_outliers, column] = q3

# %%
# data after handling outliers

for col in df.select_dtypes(exclude ='object'):
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df = df.drop(['Country','percentage expenditure','under-five deaths','thinness 5-9 years'],axis =1)
df
# Out:
#       Year  Status  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0     2015       1             65.0            263.0             22     0.01
# 1     2014       1             59.9            271.0             22     0.01
# 2     2013       1             59.9            268.0             22     0.01
# 3     2012       1             59.5            272.0             22     0.01
# 4     2011       1             59.2            275.0             22     0.01
# ...    ...     ...              ...              ...            ...      ...
# 2933  2004       1             63.2            227.0             27     4.36
# 2934  2003       1             63.2            227.0             26     4.06
# 2935  2002       1             44.8             73.0             25     4.43
# 2936  2001       1             45.3            227.0             25     1.72
# 2937  2000       1             46.0            227.0             24     1.68
#
# ...

# %% [markdown]
# ### Encodeing

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Status'] = encoder.fit_transform(df['Status'])
df['Status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# split data into numerical

numeric_col = df.select_dtypes(exclude ='object')
numeric_col = numeric_col.drop('Year',axis=1)
numeric_col.columns
# Out:
# Index(['Status', 'Life expectancy', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'Hepatitis B', 'Measles', 'BMI', 'Polio',
#        'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population',
#        'thinness  1-19 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# show distrubution using histgram after preproccessing

for col in numeric_col:
    sns.histplot(numeric_col[col],kde = True)
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### Split data

# %%
X = df.drop('Life expectancy', axis =1)
y = df['Life expectancy']

# %%
X.shape  ,y.shape
# Out:
# ((2938, 17), (2938,))

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test , y_train , y_test = train_test_split(X,y,test_size = 0.3,random_state =42)

# %%
numeric_columns = X_train.select_dtypes(include=['int64', 'float64']).columns
X_train_numeric = X_train[numeric_columns]
X_test_numeric = X_test[numeric_columns]

# %% [markdown]
# ### Standrilaze  data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_numeric)
X_test_scaled = scaler.transform(X_test_numeric)

# %% [markdown]
# ### linear Regression with CV

# %%
from sklearn.model_selection import cross_val_score,cross_val_predict
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
LR = LinearRegression()
scores = cross_val_score(LR,X_train_scaled,y_train,cv=5)
scores.mean()
# Out:
# 0.7853127602559239

# %%
LR.fit(X_train_scaled ,y_train)
y_train_pred = LR.predict(X_train_scaled)
y_pred = LR.predict(X_test_scaled)

# %% [markdown]
# ### EValuate LR

# %%
from sklearn.metrics import mean_squared_error
# calculate RMSE
rmse_train = mean_squared_error(y_train ,y_train_pred,squared = False)
rmse_test = mean_squared_error(y_test ,y_pred,squared = False)
print('RMSE for training : {:.2f}'.format(rmse_train))
print('RMSE for testing :{:.2f}'.format(rmse_test))
print('Linear Regression Model Score')
print('Train Score {:.2f}'.format(LR.score(X_train_scaled,y_train)))
print('Test Score {:.2f}'.format(LR.score(X_test_scaled,y_test)))
# Out:
# RMSE for training : 4.22
# RMSE for testing :4.14
# Linear Regression Model Score
# Train Score 0.79
# Test Score 0.81

# %%
plt.plot(y_test ,color= 'blue',label ='Actual Value')
plt.plot(y_pred ,color = 'green' , label = 'Predicted Value')
plt.title('Actual Vs Predicted Life Expectancy')
plt.legend()
plt.show()

# %%
plt.plot(y_train_pred ,color ='blue',label ='Train prediction')
plt.plot(y_pred ,color = 'red',label = 'Test prediction')
plt.legend()
plt.show()

# %%
X.columns.values
# Out:
# array(['Year', 'Status', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'Hepatitis B', 'Measles', 'BMI', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population',
#        'thinness  1-19 years', 'Income composition of resources',
#        'Schooling'], dtype=object)

# %%
features = X.columns.values
coefficients = LR.coef_
sorted_idx = np.argsort(np.abs(coefficients))
plt.barh(range(len(sorted_idx)), coefficients[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), [features[i] for i in sorted_idx])
plt.xlabel('Coefficient Magnitude')
plt.title('Linear Regression Feature Importance')
plt.show()

# %%
# Assuming you have calculated RMSE values (e.g., rmse_train, rmse_test)

rmse_train_i = int(rmse_train)  

ecophs = range(1, rmse_train_i + 1) 

plt.plot(ecophs, 'bo-', label='Training RMSE')
# plt.show()
plt.plot(ecophs, 'ro-', label='Testing RMSE')
plt.xlabel('Ecophs')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8814568562544358

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
knn = KNeighborsRegressor()
k_grid = {'n_neighbors': range(1,10)}
grid_search = GridSearchCV(knn, k_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_scaled, y_train)
print("Best K:", grid_search.best_params_['n_neighbors'])
# Get the best model from the grid search
best_knn_model = grid_search.best_estimator_
y_pred = best_knn_model.predict(X_test_scaled)
test_mse = mean_squared_error(y_test, y_pred)
print("Test Mean Squared Error:", test_mse)
# Out:
# Best K: 3
# Test Mean Squared Error: 10.093057445200301

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

knn = KNeighborsRegressor(n_neighbors =3)
knn.fit(X_train_scaled, y_train)
y_train_pred = knn.predict(X_train_scaled)
y_pred = knn.predict(X_test_scaled)
rmse_train = mean_squared_error(y_train,y_train_pred,squared= False)
rmse_test = mean_squared_error(y_test,y_pred , squared = False)
print('RMSE Train: {:.2f}',rmse_train)
print('RMSE test: {:.2f}',rmse_test)

train_score = knn.score(X_train_scaled, y_train)
test_score = knn.score(X_test_scaled, y_test)
print('Train Score {:.2f}'.format(train_score))
print('Test Score {:.2f}'.format(test_score))
# Out:
# RMSE Train: {:.2f} 2.1660553612336635
# RMSE test: {:.2f} 3.176957262098485
# Train Score 0.95
# Test Score 0.89

# %%
cv_scores = cross_val_score(knn, X_train_scaled, y_train, cv=5)
cv_scores.mean()
# Out:
# 0.8649118458991936

# %% [markdown]
# # That's it ..
# # Thank you
